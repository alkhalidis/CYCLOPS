# %%
from image_illumination_correction import artefact_correction, find_cell_nuclei_masks

# %%
images = [] # Read images into a list

# %%
# To correct artefacts in images
out_im = artefact_correction(images)

# %%
# To find nuclei and cytoplasm masks
find_cell_nuc_masks(out_im, cyt_channels)
